# %%
import import_ipynb
import stock_loop_checker
import json
from stock_market_time import is_market_open, sell_stock_time



from sma_dates import start_stop_dates
from situation_checker import situation
start_date, stop_date = start_stop_dates()
print('start date', start_date)
print('Stop date', stop_date)
# Out:
# importing Jupyter notebook from stock_loop_checker.ipynb
# importing Jupyter notebook from stock_market_time.ipynb
# importing Jupyter notebook from sma_dates.ipynb
# importing Jupyter notebook from situation_checker.ipynb
# start date 2020-3-21
# Stop date 2020-1-31

# %%
#reasd JSON with stock tickers 
import json

with open('data3.JSON') as f:
    data = json.load(f)
    
stock=(data[3])
stock
# Out:
# 'CVBF'

# %%
k= 0
p= 0
tt= 0 
loop_breaker = 0
while True:
    while is_market_open() == True:
        if tt == 0:
            with open('data3.JSON') as f:
                data = json.load(f)

            stock=(data[1])
            print('stock:',stock)
            aa = situation(stock,stop_date,start_date)
            
            tt = 1
        if aa == "BUY":     
            if k == 0:
                stock_loop_checker.buy_check_stock(stock,100)
                k= 1
        else:
            loop_breaker = 1
            break
    while sell_stock_time() == True:
        if k == 1:
            stock_loop_checker.create_order(stock,100,"sell","market","gtc")
            p= 1    
    if loop_breaker == 1:
        break
# Out:
# stock: PINC
# [*********************100%***********************]  1 of 1 completed
# buy 2020-02-04 00:00:00
# sell 2020-02-05 00:00:00
# sell 2020-02-06 00:00:00
# sell 2020-02-07 00:00:00
# sell 2020-02-10 00:00:00
# buy 2020-02-11 00:00:00
# buy 2020-02-12 00:00:00
# sell 2020-02-13 00:00:00
# buy 2020-02-14 00:00:00
# buy 2020-02-18 00:00:00
# sell 2020-02-19 00:00:00
# sell 2020-02-20 00:00:00
# sell 2020-02-21 00:00:00
# sell 2020-02-24 00:00:00
# sell 2020-02-25 00:00:00
# sell 2020-02-26 00:00:00
# sell 2020-02-27 00:00:00
# sell 2020-02-28 00:00:00
# sell 2020-03-02 00:00:00
# buy 2020-03-03 00:00:00
# buy 2020-03-04 00:00:00
# buy 2020-03-05 00:00:00
# sell 2020-03-06 00:00:00
# sell 2020-03-09 00:00:00
# buy 2020-03-10 00:00:00
# buy 2020-03-11 00:00:00
# buy 2020-03-12 00:00:00
# buy 2020-03-13 00:00:00
# buy 2020-03-16 00:00:00
# buy 2020-03-17 00:00:00
# ---------------------------------------------------------------------------
# ...

# %%
if loop_breaker == 1:
    print('breaker kicked')

# %%
for i in range(len(data)):
    k= 0
    p= 0
    tt= 0 
    loop_breaker = 0
    while True:
        while is_market_open() == True:
            if tt == 0:
                with open('data2.JSON') as f:
                    data = json.load(f)

                stock=(data[i][0])
                print('stock:',stock)
                aa = situation(stock,stop_date,start_date)

                tt = 1
            if aa == "BUY":     
                if k == 0:
                    stock_loop_checker.buy_check_stock(stock,100)
                    k= 1
            else:
                loop_breaker = 1
                break
        while sell_stock_time() == True:
            if k == 1:
                stock_loop_checker.create_order(stock,100,"sell","market","gtc")
                p= 1    
        if loop_breaker == 1:
            break
