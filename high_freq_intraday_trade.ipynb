# %%
import import_ipynb
from sma_dates import start_stop_dates
from situation_checker import situation
start_date, stop_date = start_stop_dates()
print('start date', start_date)
print('Stop date', stop_date)
import time
from stock_loop_checker import Get_financials_2, create_order
from time import sleep
import pandas as pd
import datetime
from stock_market_time import is_market_open, sell_stock_time
import json
# Out:
# importing Jupyter notebook from sma_dates.ipynb
# importing Jupyter notebook from situation_checker.ipynb
# start date 2020-3-24
# Stop date 2020-2-3
# importing Jupyter notebook from stock_loop_checker.ipynb
# importing Jupyter notebook from stock_market_time.ipynb

# %%
with open('data3.JSON') as f:
    data = json.load(f)
stock = data[1]
stock
# Out:
# 'CY'

# %%
live_p = []

cases = ['sell','sell']
pp=0
k= 0
while True:
    while is_market_open() == True:
        ttt=Get_financials_2(stock)
        live_p.append(ttt)
        aaa= pd.DataFrame(live_p)
        try:
            sma=aaa.rolling(100).mean()
            sma_22 = aaa.rolling(300).mean()
            check_price=sma[0][len(sma)-1]
            Other_check = sma_22[0][len(sma_22)-1]


            if check_price > Other_check:
                #ttty=Get_financials_2(stock)
                #if ttty > check_price:

                #print('live price is:',ttt, 'sma:',check_price,'buy now', 'at ', (datetime.datetime.now().time()))
                k = 1
                cases[1] = "BUY"

            else:
                #print('live price is:',ttt, 'sma:',check_price,'sell now', 'at ', (datetime.datetime.now().time()))
                cases[1] = "SELL"

            if   ttt < check_price:
                #print('live price is:',ttt, 'sma:',check_price,'sell now', 'at ', (datetime.datetime.now().time()))
                cases[1] = "SELL"   


            if k==1:
                #print('HWye')
                if cases[0] != cases[1]:
                    if cases[1] == "BUY":
                        create_order(stock,200,"buy","market","gtc")
                        print('BUY')
                        print('live price is:',ttt, 'sma:',check_price,'buy now', 'at ', (datetime.datetime.now().time()))
                    elif cases[1] == "SELL":
                        create_order(stock,200,"sell","market","gtc")
                        print('sell')
                        print('live price is:',ttt, 'sma:',check_price,'sell now', 'at ', (datetime.datetime.now().time()))
                        aaa =[]
                        live_p = []


        except:
            print('error')
        cases[0]=cases[1]
        sleep(1)
# Out:
# BUY
# live price is: 22.96 sma: 22.91020000000028 buy now at  12:14:14.033688
# sell
# live price is: 22.96 sma: 22.960000000000235 sell now at  12:16:22.202124
# BUY
# live price is: 22.95 sma: 22.882100000000218 buy now at  12:25:30.760845
# sell
# live price is: 22.94 sma: 22.94040000000008 sell now at  12:27:01.275289
# BUY
# live price is: 22.95 sma: 22.949999999999775 buy now at  12:33:34.354064
# sell
# live price is: 22.99 sma: 22.990099999999757 sell now at  12:41:32.158429
# BUY
# live price is: 22.99 sma: 22.98999999999983 buy now at  12:47:55.433795
# sell
# live price is: 22.99 sma: 22.98999999999983 sell now at  12:51:29.264376
# BUY
# live price is: 22.95 sma: 22.933699999999973 buy now at  13:03:06.069444
# sell
# live price is: 22.93 sma: 22.94979999999993 sell now at  13:04:20.948470
# BUY
# live price is: 22.92 sma: 22.90700000000023 buy now at  13:10:51.045172
# sell
# live price is: 22.91 sma: 22.91000000000023 sell now at  13:11:20.604675
# BUY
# live price is: 22.94 sma: 22.922000000000175 buy now at  13:21:17.822375
# sell
# live price is: 22.85 sma: 22.927900000000168 sell now at  13:22:01.658825
# BUY
# live price is: 22.85 sma: 22.83559999999997 buy now at  13:35:50.058520
# sell
# live price is: 22.86 sma: 22.864300000000025 sell now at  13:37:15.727803
# BUY
# live price is: 22.99 sma: 22.985499999999845 buy now at  13:43:39.687429
# sell
# live price is: 23.01 sma: 23.010000000000176 sell now at  13:47:40.490717
