# %%
a = 0.0
while a< 50: 
    while a<10:
        a=a+1
        print('in mini loop')
    a= a+10
    print('in big loop')
# Out:
# in mini loop
# in mini loop
# in mini loop
# in mini loop
# in mini loop
# in mini loop
# in mini loop
# in mini loop
# in mini loop
# in mini loop
# in big loop
# in big loop
# in big loop
# in big loop

# %%
from datetime import datetime, time

# %%
then = time(14,00)

# %%
if now > then: 
    print('now is greater than then')
else: 
    print('then is greater than now')
# Out:
# then is greater than now

# %%
def is_market_open():
    market_open = time(8,30)
    market_close = time(15,0)
    
    now = datetime.now().time()
    
    if now < market_close:
        if now > market_open:
            return True
        else:
            return False
    else:
        return False

# %%
is_market_open()
# Out:
# False

# %%
while True:
    while is_market_open() == True:
        print('market is open')
    p=0
