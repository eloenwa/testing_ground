# %%
import import_ipynb
import stock_loop_checker
# Out:
# importing Jupyter notebook from stock_loop_checker.ipynb

# %%
#reasd JSON with stock tickers 
import json

with open('data2.JSON') as f:
    data = json.load(f)
    
stock=(data[3][0])
stock
# Out:
# 'WYNN'

# %%
stock_loop_checker.buy_check_stock(stock,100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\genericpath.py in exists(path)
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\Elo-PC/.netrc'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2e0cb14059ec> in <module>
# ----> 1 stock_loop_checker.buy_check_stock(stock,100)
#
# ~\OneDrive\stock_trading\testing_ground\stock_loop_checker.ipynb in buy_check_stock(stock, number_of_stock)
#
# ~\OneDrive\stock_trading\testing_ground\stock_loop_checker.ipynb in Get_financials_2(Stock)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ...
