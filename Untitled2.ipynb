# %%
#reasd JSON with stock tickers 
import json

with open('data2.JSON') as f:
    data = json.load(f)
    
print(data)
# Out:
# [['CY', 4103.711004790975], ['SFM', 3155.21558173826], ['ERIE', 954.0302171580189], ['PINC', 624.7464827248043], ['CBSH', 615.0403370269294], ['PBCT', 570.4365499666986], ['CGNX', 564.073787002473], ['CVBF', 452.5063203304892], ['WDFC', 351.88827986231524], ['SFNC', 341.33658829551246], ['BCPC', 333.3519384955394], ['NTAP', 329.6375107869887], ['MGEE', 309.7737229700193], ['RGLD', 297.7571641640508], ['CASY', 279.37907284146024], ['DORM', 271.8364820169981], ['IPGP', 254.03112582151482], ['WAFD', 251.72978368527384], ['SHEN', 245.28495509256652], ['POWI', 241.6928008412305], ['ZBRA', 238.0880479052463], ['EHTH', 221.43103691728584], ['SAIA', 207.4926503541841], ['AMED', 177.26006332632082], ['RGEN', 172.085635809434]]

# %%
for i in data: 
    print(i)
# Out:
# ['CY', 4103.711004790975]
# ['SFM', 3155.21558173826]
# ['ERIE', 954.0302171580189]
# ['PINC', 624.7464827248043]
# ['CBSH', 615.0403370269294]
# ['PBCT', 570.4365499666986]
# ['CGNX', 564.073787002473]
# ['CVBF', 452.5063203304892]
# ['WDFC', 351.88827986231524]
# ['SFNC', 341.33658829551246]
# ['BCPC', 333.3519384955394]
# ['NTAP', 329.6375107869887]
# ['MGEE', 309.7737229700193]
# ['RGLD', 297.7571641640508]
# ['CASY', 279.37907284146024]
# ['DORM', 271.8364820169981]
# ['IPGP', 254.03112582151482]
# ['WAFD', 251.72978368527384]
# ['SHEN', 245.28495509256652]
# ['POWI', 241.6928008412305]
# ['ZBRA', 238.0880479052463]
# ['EHTH', 221.43103691728584]
# ['SAIA', 207.4926503541841]
# ['AMED', 177.26006332632082]
# ['RGEN', 172.085635809434]
