# %%
initial_invst = 170
daily_growth = 42
number_of_days =1

# %%
new_value = initial_invst*(1+(daily_growth/100))**(number_of_days)
'${:,.2f}'.format(new_value)
# Out:
# '$241.40'

# %%
return_perct = (new_value-initial_invst)/initial_invst*100
return_perct
# Out:
# 41.999999999999986

# %%
extra_cash = new_value-initial_invst
extra_cash*0.65
# Out:
# 46.40999999999999

# %%
print('${:,.2f}'.format(extra_cash*0.7+initial_invst), 'after tax')
# Out:
# $219.98 after tax
